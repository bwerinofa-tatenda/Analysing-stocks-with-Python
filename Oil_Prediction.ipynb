# %% [markdown]
# # Oil Price Prediction Using Machine Learning

# %%
# LinearRegression is a machine learning library for linear regression 
from sklearn.linear_model import LinearRegression 

# pandas and numpy are used for data manipulation 
import pandas as pd 
import numpy as np 

# matplotlib and seaborn are used for plotting graphs 
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# Read data 
Df = yf.download('USO','2016-01-01','2018-09-10')

# Only keep close columns 
Df=Df[['Close']] 

# Drop rows with missing values 
Df= Df.dropna() 

# Plot the closing price of GLD 
Df.Close.plot(figsize=(10,5)) 
plt.ylabel("OIL ETF Prices")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Define explanatory variables
Df['S_3'] = Df['Close'].shift(1).rolling(window=3).mean() 
Df['S_9']= Df['Close'].shift(1).rolling(window=9).mean() 
Df= Df.dropna() 
X = Df[['S_3','S_9']] 
X.head()
# Out:
#                   S_3        S_9
# Date
# 2016-01-14  73.360001  79.964444
# 2016-01-15  73.306666  78.391110
# 2016-01-19  72.293332  76.444444
# 2016-01-20  70.693331  74.515555
# 2016-01-21  68.053332  72.853333

# %%
# Define dependent variable
y = Df['Close']
y.head()
# Out:
# Date
# 2016-01-14    73.839996
# 2016-01-15    70.320000
# 2016-01-19    67.919998
# 2016-01-20    65.919998
# 2016-01-21    68.480003
# Name: Close, dtype: float64

# %%
# Split the data into train and test dataset
t=.8 
t = int(t*len(Df)) 

# Train dataset 
X_train = X[:t] 
y_train = y[:t]  

# Test dataset 
X_test = X[t:] 
y_test = y[t:]

# %%
# Create a linear regression model
# Y = m1 * X1 + m2 * X2 + C
# Gold ETF price = m1 * 3 days moving average + m2 * 15 days moving average + c
linear = LinearRegression().fit(X_train,y_train) 
print("MJ ETF Price =", round(linear.coef_[0],2), "* 3 Days Moving Average", round(linear.coef_[1],2), "* 9 Days Moving Average +", round(linear.intercept_,2))
# Out:
# MJ ETF Price = 1.19 * 3 Days Moving Average -0.22 * 9 Days Moving Average + 2.99

# %%
# Predicting the Oil ETF prices
predicted_price = linear.predict(X_test)  
predicted_price = pd.DataFrame(predicted_price,index=y_test.index,columns = ['price'])  
predicted_price.plot(figsize=(10,5))  
y_test.plot()  
plt.legend(['predicted_price','actual_price'])  
plt.ylabel("USO ETF Price")  
plt.show()

# %%
r2_score = linear.score(X[t:],y[t:])*100  
float("{0:.2f}".format(r2_score))
# Out:
# 86.11

# %% [markdown]
# Oil Stock

# %%
Oil_stock = ['PBR', 'VALE', 'RIG', 'WLL']

# %%
start = '2016-01-01'
end = '2018-09-10'
df = yf.download(Oil_stock,start,end)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
stocks = pd.DataFrame(df['Adj Close'])
stocks.head()
# Out:
#                  PBR    RIG      VALE        WLL
# Date
# 2015-12-31  3.132119  12.38  2.385589  37.491364
# 2016-01-04  3.102983  12.55  2.291325  37.848801
# 2016-01-05  3.044711  12.15  2.284074  35.902748
# 2016-01-06  2.877179  11.52  2.110049  31.414902
# 2016-01-07  2.775203  11.00  1.965029  29.945433

# %%
plt.figure(figsize=(16,8))
plt.plot(stocks)
plt.title('Oil Stock Adj Close')
plt.legend(stocks)
plt.grid()
plt.ylabel('Price')
plt.xlabel('Date')
plt.show()

# %%
stocks.plot(grid = True, figsize=(12,8))

# %%
stock_return = stocks.apply(lambda x: x / x[0])
stock_return.head()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2015-12-31  1.000000  1.000000  1.000000  1.000000
# 2016-01-04  0.990698  1.013732  0.960486  1.009534
# 2016-01-05  0.972093  0.981422  0.957447  0.957627
# 2016-01-06  0.918604  0.930533  0.884498  0.837924
# 2016-01-07  0.886046  0.888530  0.823708  0.798729

# %%
stock_return.plot(grid = True, figsize=(12,8)).axhline(y = 1, color = "black", lw = 2)
plt.axhline(y=4, color = 'red', lw=2)

# %%
stock_return = stocks.pct_change(1).dropna()
stock_return.head()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2016-01-04 -0.009302  0.013732 -0.039514  0.009534
# 2016-01-05 -0.018779 -0.031873 -0.003165 -0.051416
# 2016-01-06 -0.055024 -0.051852 -0.076190 -0.125000
# 2016-01-07 -0.035443 -0.045139 -0.068728 -0.046776
# 2016-01-08 -0.015748 -0.022727 -0.040591  0.030504

# %%
stock_return.tail()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2018-08-31  0.035238 -0.005747  0.002278  0.011122
# 2018-09-04 -0.043238 -0.066887 -0.049242 -0.007857
# 2018-09-05  0.015385 -0.008850  0.005578  0.002376
# 2018-09-06  0.006629 -0.033036  0.029319 -0.059648
# 2018-09-07  0.038570  0.001847  0.001540 -0.008192

# %%
stock_return.plot(grid = True, figsize=(12,8)).axhline(y = 1, color = "black", lw = 2)

# %%
stock_change = stocks.apply(lambda x: np.log(x) - np.log(x.shift(1))) # shift moves dates back by 1.
stock_change.head()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2015-12-31       NaN       NaN       NaN       NaN
# 2016-01-04 -0.009346  0.013638 -0.040316  0.009489
# 2016-01-05 -0.018958 -0.032392 -0.003170 -0.052785
# 2016-01-06 -0.056596 -0.053244 -0.079249 -0.133531
# 2016-01-07 -0.036086 -0.046189 -0.071204 -0.047906

# %%
stock_change.plot(grid = True, figsize=(12,8)).axhline(y = 0, color = "black", lw = 2)

# %%
sns.pairplot(stock_change[1:])

# %%
stock_change.idxmin()
# Out:
# PBR    2017-05-18
# RIG    2016-03-08
# VALE   2016-03-08
# WLL    2016-01-19
# dtype: datetime64[ns]

# %%
stock_change.idxmax()
# Out:
# PBR    2016-02-22
# RIG    2016-03-04
# VALE   2016-02-04
# WLL    2016-11-30
# dtype: datetime64[ns]

# %%
stock_change.std()
# Out:
# PBR     0.034025
# RIG     0.032974
# VALE    0.034243
# WLL     0.049428
# dtype: float64

# %%
# Sharpe Ratio for Each Stocks
N = 252
returns = stocks.pct_change().dropna()
annualised_sharpe = np.sqrt(N) * returns.mean() / returns.std()
annualised_sharpe
# Out:
# PBR     0.924597
# RIG     0.167299
# VALE    1.269936
# WLL     0.495022
# dtype: float64

# %%
annualised_sharpe.index
# Out:
# Index(['PBR', 'RIG', 'VALE', 'WLL'], dtype='object')

# %%
annualised_sharpe.sort_values()
# Out:
# RIG     0.167299
# WLL     0.495022
# PBR     0.924597
# VALE    1.269936
# dtype: float64

# %%
annualised_sharpe.sort_index()
# Out:
# PBR     0.924597
# RIG     0.167299
# VALE    1.269936
# WLL     0.495022
# dtype: float64

# %%
# Equity Sharpe - Buy and Hold
N = 252 # Number of trading in a year
risk = 0.01
excess_daily_ret =  returns - (risk * N)
equity_sharpe = np.sqrt(N) * excess_daily_ret.mean() / excess_daily_ret.std()
equity_sharpe.sort_values()
# Out:
# RIG    -1203.761550
# PBR    -1176.293660
# VALE   -1159.670862
# WLL     -800.575676
# dtype: float64

# %%
# Market Neutral Sharpe
start = '2016-01-01'
end = '2018-09-10'
market = 'SPY'
ticker = ['PBR', 'VALE', 'RIG', 'WLL']
bench = yf.download(market,start,end)
stocks = yf.download(ticker,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  4 of 4 completed

# %%
tick = pd.DataFrame(stocks['Adj Close'])
tick.head()
# Out:
#                  PBR    RIG      VALE        WLL
# Date
# 2015-12-31  3.132119  12.38  2.385589  37.491360
# 2016-01-04  3.102983  12.55  2.291325  37.848804
# 2016-01-05  3.044711  12.15  2.284074  35.902748
# 2016-01-06  2.877179  11.52  2.110050  31.414902
# 2016-01-07  2.775203  11.00  1.965029  29.945433

# %%
daily_rets = tick.pct_change().dropna()
daily_rets.head()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2016-01-04 -0.009302  0.013732 -0.039514  0.009534
# 2016-01-05 -0.018779 -0.031873 -0.003165 -0.051417
# 2016-01-06 -0.055024 -0.051852 -0.076190 -0.125000
# 2016-01-07 -0.035443 -0.045139 -0.068729 -0.046776
# 2016-01-08 -0.015748 -0.022727 -0.040590  0.030504

# %%
bench_rets = bench['Adj Close'].pct_change().dropna()
bench_rets.head()
# Out:
# Date
# 2016-01-04   -0.013980
# 2016-01-05    0.001692
# 2016-01-06   -0.012614
# 2016-01-07   -0.023992
# 2016-01-08   -0.010977
# Name: Adj Close, dtype: float64

# %%
strat = (daily_rets.sub(bench_rets, axis=0))/2
strat.head()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2016-01-04  0.002339  0.013856 -0.012767  0.011757
# 2016-01-05 -0.010236 -0.016782 -0.002428 -0.026554
# 2016-01-06 -0.021205 -0.019619 -0.031788 -0.056193
# 2016-01-07 -0.005726 -0.010574 -0.022369 -0.011392
# 2016-01-08 -0.002386 -0.005875 -0.014807  0.020740

# %%
N = 252
market_neutral_sharpe = np.sqrt(N) * strat.mean() / strat.std()
market_neutral_sharpe.sort_values()
# Out:
# RIG    -0.131332
# WLL     0.315320
# PBR     0.690208
# VALE    1.071197
# dtype: float64
